# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/Users/leonidsim/Desktop/Metis/MTA01-11-2020.txt")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206073 entries, 0 to 206072
# Data columns (total 11 columns):
# C/A                                                                     206073 non-null object
# UNIT                                                                    206073 non-null object
# SCP                                                                     206073 non-null object
# STATION                                                                 206073 non-null object
# LINENAME                                                                206073 non-null object
# DIVISION                                                                206073 non-null object
# DATE                                                                    206073 non-null object
# TIME                                                                    206073 non-null object
# DESC                                                                    206073 non-null object
# ...

# %%
df['Datetime'] = pd.to_datetime(df['DATE'].apply(str)+' '+df['TIME'])

# %%
df.head(20)
# Out:
#      C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0   A002  R051  02-00-00   59 ST  NQR456W      BMT  01/04/2020  03:00:00
# 1   A002  R051  02-00-00   59 ST  NQR456W      BMT  01/04/2020  07:00:00
# 2   A002  R051  02-00-00   59 ST  NQR456W      BMT  01/04/2020  11:00:00
# 3   A002  R051  02-00-00   59 ST  NQR456W      BMT  01/04/2020  15:00:00
# 4   A002  R051  02-00-00   59 ST  NQR456W      BMT  01/04/2020  19:00:00
# 5   A002  R051  02-00-00   59 ST  NQR456W      BMT  01/04/2020  23:00:00
# 6   A002  R051  02-00-00   59 ST  NQR456W      BMT  01/05/2020  03:00:00
# 7   A002  R051  02-00-00   59 ST  NQR456W      BMT  01/05/2020  07:00:00
# 8   A002  R051  02-00-00   59 ST  NQR456W      BMT  01/05/2020  11:00:00
# 9   A002  R051  02-00-00   59 ST  NQR456W      BMT  01/05/2020  15:00:00
# 10  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/05/2020  19:00:00
# 11  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/05/2020  23:00:00
# ...

# %%
df['Turnstile'] = df['C/A'] + df['UNIT'] + df['SCP']

# %%
df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/04/2020  03:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/04/2020  07:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/04/2020  11:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/04/2020  15:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/04/2020  19:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  7331213
# 1  REGULAR  7331224
# 2  REGULAR  7331281
# 3  REGULAR  7331454
# 4  REGULAR  7331759
#
#    EXITS                                                                 \
# 0                                            2484849
# 1                                            2484861
# 2                                            2484936
# 3                                            2485014
# 4                                            2485106
#
#              Datetime         Turnstile
# ...

# %%
df["Day_Name"] = df["Datetime"].dt.day_name()

# %%
df.head(50)
# Out:
#      C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0   A002  R051  02-00-00   59 ST  NQR456W      BMT  01/04/2020  03:00:00
# 1   A002  R051  02-00-00   59 ST  NQR456W      BMT  01/04/2020  07:00:00
# 2   A002  R051  02-00-00   59 ST  NQR456W      BMT  01/04/2020  11:00:00
# 3   A002  R051  02-00-00   59 ST  NQR456W      BMT  01/04/2020  15:00:00
# 4   A002  R051  02-00-00   59 ST  NQR456W      BMT  01/04/2020  19:00:00
# 5   A002  R051  02-00-00   59 ST  NQR456W      BMT  01/04/2020  23:00:00
# 6   A002  R051  02-00-00   59 ST  NQR456W      BMT  01/05/2020  03:00:00
# 7   A002  R051  02-00-00   59 ST  NQR456W      BMT  01/05/2020  07:00:00
# 8   A002  R051  02-00-00   59 ST  NQR456W      BMT  01/05/2020  11:00:00
# 9   A002  R051  02-00-00   59 ST  NQR456W      BMT  01/05/2020  15:00:00
# 10  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/05/2020  19:00:00
# 11  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/05/2020  23:00:00
# ...

# %%
mask = df['Day_Name'] != 'Saturday'

# %%
df_weekdays = df[(df["Day_Name"] != "Saturday") & (df["Day_Name"] != "Sunday")]

# %%
df_final = df_weekdays[(df_weekdays["TIME"] >= "07:00:00") & (df_weekdays["TIME"] <= "11:00:00")]

# %%
df_final_2 = df_final.groupby(['Turnstile','DATE'])

df_final.groupby(['Turnstile','DATE']).transform(lambda g: g.shift(-1) - g)
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 13       A002  R051  02-00-00          59 ST  NQR456W      BMT  01/06/2020
# 14       A002  R051  02-00-00          59 ST  NQR456W      BMT  01/06/2020
# 19       A002  R051  02-00-00          59 ST  NQR456W      BMT  01/07/2020
# 20       A002  R051  02-00-00          59 ST  NQR456W      BMT  01/07/2020
# 25       A002  R051  02-00-00          59 ST  NQR456W      BMT  01/08/2020
# ...       ...   ...       ...            ...      ...      ...         ...
# 206045  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  01/06/2020
# 206051  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  01/07/2020
# 206057  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  01/08/2020
# 206063  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  01/09/2020
# 206069  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  01/10/2020
#
#             TIME     DESC  ENTRIES  \
# ...

# %%
df_final_2['Daily'] = df_final
daily_max = df_final.groupby(['Turnstile','DATE']).agg({'ENTRIES': 'max'}).reset_index()
daily.head(100)

7332574 - 7332705
#A002R05102-00-00
# Out:
# -131

# %%
#daily_max = df_full.groupby(['Turnstile',‘DATE’]).agg({'Entiries':‘max’}).reset_index()

df_final[df_final['Turnstile']== 'A002R05102-00-00']
# Out:
#      C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 13  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/06/2020  07:00:00
# 14  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/06/2020  11:00:00
# 19  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/07/2020  07:00:00
# 20  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/07/2020  11:00:00
# 25  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/08/2020  07:00:00
# 26  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/08/2020  11:00:00
# 31  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/09/2020  07:00:00
# 32  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/09/2020  11:00:00
# 37  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/10/2020  07:00:00
# 38  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/10/2020  11:00:00
#
#        DESC  ENTRIES  \
# 13  REGULAR  7332574
# 14  REGULAR  7332705
# 19  REGULAR  7333921
# 20  REGULAR  7334052
# 25  REGULAR  7335300
# 26  REGULAR  7335421
# ...

# %%
#Take the max entries for a turnstile - min entries for turnstile = For each turnstile, delta 

monthly_max = 

daily_min = df_final.groupby(['Turnstile','DATE']).agg({'ENTRIES': 'min'}).reset_index()
daily_min.head(100)
# Out:
#            Turnstile        DATE  ENTRIES
# 0   A002R05102-00-00  01/06/2020  7332574
# 1   A002R05102-00-00  01/07/2020  7333921
# 2   A002R05102-00-00  01/08/2020  7335300
# 3   A002R05102-00-00  01/09/2020  7336751
# 4   A002R05102-00-00  01/10/2020  7338175
# ..               ...         ...      ...
# 95  A006R07900-03-02  01/06/2020   843231
# 96  A006R07900-03-02  01/07/2020   845295
# 97  A006R07900-03-02  01/08/2020   847458
# 98  A006R07900-03-02  01/09/2020   849662
# 99  A006R07900-03-02  01/10/2020   851894
#
# [100 rows x 3 columns]

# %%
df_final['Delta'] = daily_max['ENTRIES'] - daily_min['ENTRIES']
# Out:
# /Users/leonidsim/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_final.head(100)
# Out:
#       C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 13   A002  R051  02-00-00   59 ST  NQR456W      BMT  01/06/2020  07:00:00
# 14   A002  R051  02-00-00   59 ST  NQR456W      BMT  01/06/2020  11:00:00
# 19   A002  R051  02-00-00   59 ST  NQR456W      BMT  01/07/2020  07:00:00
# 20   A002  R051  02-00-00   59 ST  NQR456W      BMT  01/07/2020  11:00:00
# 25   A002  R051  02-00-00   59 ST  NQR456W      BMT  01/08/2020  07:00:00
# ..    ...   ...       ...     ...      ...      ...         ...       ...
# 404  A002  R051  02-05-00   59 ST  NQR456W      BMT  01/08/2020  11:00:00
# 409  A002  R051  02-05-00   59 ST  NQR456W      BMT  01/09/2020  07:00:00
# 410  A002  R051  02-05-00   59 ST  NQR456W      BMT  01/09/2020  11:00:00
# 415  A002  R051  02-05-00   59 ST  NQR456W      BMT  01/10/2020  07:00:00
# 416  A002  R051  02-05-00   59 ST  NQR456W      BMT  01/10/2020  11:00:00
#
#         DESC  ENTRIES  \
# 13   REGULAR  7332574
# 14   REGULAR  7332705
# ...

# %%
df_final[df_final['Turnstile']== 'A002R05102-00-00']
# Out:
#      C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 13  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/06/2020  07:00:00
# 14  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/06/2020  11:00:00
# 19  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/07/2020  07:00:00
# 20  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/07/2020  11:00:00
# 25  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/08/2020  07:00:00
# 26  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/08/2020  11:00:00
# 31  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/09/2020  07:00:00
# 32  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/09/2020  11:00:00
# 37  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/10/2020  07:00:00
# 38  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/10/2020  11:00:00
#
#        DESC  ENTRIES  \
# 13  REGULAR  7332574
# 14  REGULAR  7332705
# 19  REGULAR  7333921
# 20  REGULAR  7334052
# 25  REGULAR  7335300
# 26  REGULAR  7335421
# ...

# %%
7335300 - 7335421
# Out:
# -121

# %%
67 + 53
# Out:
# 120

# %%
# !pwd
# Out:
# /Users/leonidsim/Desktop/Metis/nyc20_ds23/curriculum/project-01/matplotlib
